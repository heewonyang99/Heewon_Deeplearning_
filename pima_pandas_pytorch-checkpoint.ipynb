# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r'C:\Users\data set/pima-indians-diabetes.csv',
               names = ["pregnant", "plasma", "pressure", "thickness", "insulin", "BMI", "pedigree", "age", "class"])

# %%
print(df.head(5))
# Out:
#    pregnant  plasma  pressure  thickness  insulin   BMI  pedigree  age  class
# 0         6     148        72         35        0  33.6     0.627   50      1
# 1         1      85        66         29        0  26.6     0.351   31      0
# 2         8     183        64          0        0  23.3     0.672   32      1
# 3         1      89        66         23       94  28.1     0.167   21      0
# 4         0     137        40         35      168  43.1     2.288   33      1

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pregnant   768 non-null    int64
#  1   plasma     768 non-null    int64
#  2   pressure   768 non-null    int64
#  3   thickness  768 non-null    int64
#  4   insulin    768 non-null    int64
#  5   BMI        768 non-null    float64
#  6   pedigree   768 non-null    float64
#  7   age        768 non-null    int64
#  8   class      768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None

# %%
print(df.describe())
# Out:
#          pregnant      plasma    pressure   thickness     insulin         BMI  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#          pedigree         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
print(df[['pregnant', 'class']])
# Out:
#      pregnant  class
# 0           6      1
# 1           1      0
# 2           8      1
# 3           1      0
# 4           0      1
# ..        ...    ...
# 763        10      0
# 764         2      0
# 765         5      0
# 766         1      1
# 767         1      0
#
# [768 rows x 2 columns]

# %%
# 데이터 간의 상관관계를 그래프로 표현해 봅니다.

colormap = plt.cm.gist_heat   #그래프의 색상 구성을 정합니다.
plt.figure(figsize=(12,12))   #그래프의 크기를 정합니다.

# 그래프의 속성을 결정합니다. vmax의 값을 0.5로 지정해 0.5에 가까울 수록 밝은 색으로 표시되게 합니다.
sns.heatmap(df.corr(),linewidths=0.1,vmax=0.5, cmap=colormap, linecolor='white', annot=True)
plt.show()

# %%
grid = sns.FacetGrid(df, col='class')
grid.map(plt.hist, 'plasma',  bins=10)
plt.show()

# %%
# Out:
# Epoch 1/200
# 77/77 [==============================] - 0s 2ms/step - loss: 10.5440 - accuracy: 0.6159
# Epoch 2/200
# 77/77 [==============================] - 0s 1ms/step - loss: 5.4367 - accuracy: 0.6029
# Epoch 3/200
# 77/77 [==============================] - 0s 984us/step - loss: 2.9292 - accuracy: 0.5208
# Epoch 4/200
# 77/77 [==============================] - 0s 1ms/step - loss: 1.5346 - accuracy: 0.5208
# Epoch 5/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.8896 - accuracy: 0.5000
# Epoch 6/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.8072 - accuracy: 0.5234
# Epoch 7/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7655 - accuracy: 0.6549
# Epoch 8/200
# 77/77 [==============================] - 0s 946us/step - loss: 0.7306 - accuracy: 0.6628
# Epoch 9/200
# 77/77 [==============================] - 0s 920us/step - loss: 0.6943 - accuracy: 0.6706
# Epoch 10/200
# ...

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.nn.init as init

import numpy

from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

import tensorflow as tf

numpy.random.seed(3)
tf.random.set_seed(3)


dataset = numpy.loadtxt(r'C:\Users\data set/pima-indians-diabetes.csv',delimiter = ",", dtype = numpy.float32)

X = torch.FloatTensor(dataset[:,0:-1])
Y = torch.FloatTensor(dataset[:,[-1]])


model = nn.Sequential(
    nn.Linear(8,12), 
    nn.ReLU(), 
    nn.Linear(12,8), 
    nn.ReLU(), 
    nn.Linear(8,1), 
    nn.Sigmoid())

epochs = 100

loss_fnc = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr = 0.02)

for epoch in range (epochs+ 1):
    optimizer.zero_grad()
    hypothesis = model(X)
    loss = loss_fnc(hypothesis, Y)
    loss.backward()
    optimizer.step()
    
    print('Epoch {:4d}/{}   Cost: {:.6f}'.format(epoch, epochs, loss.item()))
# Out:
# Epoch    0/100   Cost: 2.583797
# Epoch    1/100   Cost: 1.429602
# Epoch    2/100   Cost: 0.911524
# Epoch    3/100   Cost: 0.739164
# Epoch    4/100   Cost: 0.728918
# Epoch    5/100   Cost: 0.733596
# Epoch    6/100   Cost: 0.732802
# Epoch    7/100   Cost: 0.725461
# Epoch    8/100   Cost: 0.717642
# Epoch    9/100   Cost: 0.712223
# Epoch   10/100   Cost: 0.708944
# Epoch   11/100   Cost: 0.707181
# Epoch   12/100   Cost: 0.706057
# Epoch   13/100   Cost: 0.704271
# Epoch   14/100   Cost: 0.701038
# Epoch   15/100   Cost: 0.696847
# Epoch   16/100   Cost: 0.692788
# Epoch   17/100   Cost: 0.689453
# Epoch   18/100   Cost: 0.686578
# Epoch   19/100   Cost: 0.683948
# Epoch   20/100   Cost: 0.681748
# Epoch   21/100   Cost: 0.679536
# Epoch   22/100   Cost: 0.677240
# Epoch   23/100   Cost: 0.674960
# Epoch   24/100   Cost: 0.672929
# Epoch   25/100   Cost: 0.671031
# Epoch   26/100   Cost: 0.669177
# Epoch   27/100   Cost: 0.667398
# Epoch   28/100   Cost: 0.665811
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r'C:\Users\data set/pima-indians-diabetes.csv',
               names = ["pregnant", "plasma", "pressure", "thickness", "insulin", "BMI", "pedigree", "age", "class"])

colormap = plt.cm.twilight

plt.figure(figsize=(9, 8)) 

sns.heatmap(df.corr(),linewidths=0.1,vmax=0.5, cmap=colormap, linecolor='white', annot=True)
plt.show()

# %%
Menu = ['김치전', '파전', '막걸리', '참이슬', '테라', '사이다']
Price = {'김치전': 10000, '파전': 12000, '막걸리': 7000, '참이슬': 4000, '테라': 5000, '사이다': 2000}
yourOrder = []
totalPrice = 0

import tkinter
window = tkinter.Tk()
window.geometry("250x450")
window.configure(background='AntiqueWhite')
var=tkinter.IntVar()


def countUpM0():
    global cntM0
    global totalPrice
    cntM0 += 1
    labelM0.config(text=str(cntM0))
    priceLabelM0.config(text=str(10000 * cntM0))
    orderM0 = var.get()
    for i in range(orderM0 + 1):
        yourOrder.append(Menu[0])
        totalPrice += Price['김치전']
    yourPriceLabel2.config(text=str(totalPrice))

def countDownM0():
    global cntM0
    global totalPrice
    cntM0 -= 1
    import tkinter.messagebox
    if cntM0 < 0:
        tkinter.messagebox.showerror('showerror', '잘못된 입력입니다.')
        cntM0 = 00
    labelM0.config(text=str(cntM0))
    priceLabelM0.config(text=str(10000 * cntM0))
    orderM0 = var.get()
    for i in range(orderM0 + 1):
        if '김치전' in yourOrder:
            yourOrder.remove(Menu[0])
            totalPrice -= Price['김치전']
    yourPriceLabel2.config(text=str(totalPrice))


def countUpM1():
    global cntM1
    global totalPrice
    cntM1 += 1
    labelM1.config(text=str(cntM1))
    priceLabelM1.config(text=str(12000 * cntM1))
    orderM1 = var.get()
    for i in range(orderM1 + 1):
        yourOrder.append(Menu[1])
        totalPrice += Price['파전']
    yourPriceLabel2.config(text=str(totalPrice))

def countDownM1():
    global cntM1
    global totalPrice
    cntM1 -= 1
    import tkinter.messagebox
    if cntM1 < 0:
        tkinter.messagebox.showerror('showerror', '잘못된 입력입니다.')
        cntM1 = 00
    labelM1.config(text=str(cntM1))
    priceLabelM1.config(text=str(12000 * cntM1))
    orderM1 = var.get()
    for i in range(orderM1 + 1):
        if '파전' in yourOrder:
            yourOrder.remove(Menu[1])
            totalPrice -= Price['파전']
    yourPriceLabel2.config(text=str(totalPrice))



def countUpM2():
    global cntM2
    global totalPrice
    cntM2 += 1
    labelM2.config(text=str(cntM2))
    priceLabelM2.config(text=str(7000 * cntM2))
    orderM2 = var.get()
    for i in range(orderM2 +1):
        yourOrder.append(Menu[2])
        totalPrice += Price['막걸리']
    yourPriceLabel2.config(text=str(totalPrice))

def countDownM2():
    global cntM2
    global totalPrice
    cntM2 -= 1
    import tkinter.messagebox
    if cntM2 < 0:
        tkinter.messagebox.showerror('showerror', '잘못된 입력입니다.')
        cntM2 = 00
    labelM2.config(text=str(cntM2))
    priceLabelM2.config(text=str(7000 * cntM2))
    orderM2 = var.get()
    for i in range(orderM2 + 1):
        if '막걸리' in yourOrder:
            yourOrder.remove(Menu[2])
            totalPrice -= Price['막걸리']
    yourPriceLabel2.config(text=str(totalPrice))


def countUpM3():
    global cntM3
    global totalPrice
    cntM3 += 1
    labelM3.config(text=str(cntM3))
    priceLabelM3.config(text=str(4000 * cntM3))
    orderM3 = var.get()
    for i in range(orderM3 +1):
        yourOrder.append(Menu[3])
        totalPrice += Price['참이슬']
    yourPriceLabel2.config(text=str(totalPrice))

def countDownM3():
    global cntM3
    global totalPrice
    cntM3 -= 1
    import tkinter.messagebox
    if cntM3 < 0:
        tkinter.messagebox.showerror('showerror', '잘못된 입력입니다.')
        cntM3 = 00
    labelM3.config(text=str(cntM3))
    priceLabelM3.config(text=str(4000 * cntM3))
    orderM3 = var.get()
    for i in range(orderM3 + 1):
        if '참이슬' in yourOrder:
            yourOrder.remove(Menu[3])
            totalPrice -= Price['참이슬']
    yourPriceLabel2.config(text=str(totalPrice))


def countUpM4():
    global cntM4
    global totalPrice
    cntM4 += 1
    labelM4.config(text=str(cntM4))
    priceLabelM4.config(text=str(5000 * cntM4))
    orderM4 = var.get()
    for i in range(orderM4 +1):
        yourOrder.append(Menu[4])
        totalPrice += Price['테라']
    yourPriceLabel2.config(text=str(totalPrice))

def countDownM4():
    global cntM4
    global totalPrice
    cntM4 -= 1
    import tkinter.messagebox
    if cntM4 < 0:
        tkinter.messagebox.showerror('showerror', '잘못된 입력입니다.')
        cntM4 = 00
    labelM4.config(text=str(cntM4))
    priceLabelM4.config(text=str(5000 * cntM4))
    orderM4 = var.get()
    for i in range(orderM4 + 1):
        if '테라' in yourOrder:
            yourOrder.remove(Menu[4])
            totalPrice -= Price['테라']
    yourPriceLabel2.config(text=str(totalPrice))


def countUpM5():
    global cntM5
    global totalPrice
    cntM5 += 1
    labelM5.config(text=str(cntM5))
    priceLabelM5.config(text=str(2000 * cntM5))
    orderM5 = var.get()
    for i in range(orderM5 +1):
        yourOrder.append(Menu[5])
        totalPrice += Price['사이다']
    yourPriceLabel2.config(text=str(totalPrice))

def countDownM5():
    global cntM5
    global totalPrice
    cntM5 -= 1
    import tkinter.messagebox
    if cntM5 < 0:
        tkinter.messagebox.showerror('showerror', '잘못된 입력입니다.')
        cntM5 = 00
    labelM5.config(text=str(cntM5))
    priceLabelM5.config(text=str(2000 * cntM5))
    orderM5 = var.get()
    for i in range(orderM5 + 1):
        if '사이다' in yourOrder:
            yourOrder.remove(Menu[5])
            totalPrice -= Price['사이다']
    yourPriceLabel2.config(text=str(totalPrice))


def buttonExit():
    global totalPrice
    import tkinter.messagebox
    tkinter.messagebox.askokcancel('askokcancel', '주문을 완료하시겠습니까?')
    print('\n'+ '주문 내역'+ '\n')
    if cntM0 != 0:
        print('%-14s'%'김치전', '%-3d'%cntM0, '%7d' %(Price['김치전']*cntM0) +'원')
    if cntM1 != 0:
        print('%-15s'%'파전', '%-3d'%cntM1, '%7d'%(Price['파전']*cntM1) +'원' )
    if cntM2 != 0:
        print('%-14s'%'막걸리', '%-3d'%cntM2, '%7d'%(Price['막걸리']*cntM2) +'원')
    if cntM3 != 0:
        print('%-14s'%'참이슬', '%-3d'%cntM3, '%7d'%(Price['참이슬']*cntM3) +'원' )
    if cntM4 != 0:
        print('%-15s'%'테라', '%-3d'%cntM4, '%7d'%(Price['테라']*cntM4) +'원' )
    if cntM5 != 0:
        print('%-14s'% '사이다', '%-3d'%cntM5, '%7d'%(Price['사이다'] * cntM5) +'원')

    print('\n' + '결제 금액' + '\t'*3 +'       ' + str(totalPrice) + '원')
    exit()

cntM0 = cntM1= cntM2 = cntM3 = cntM4 = cntM5 = 0
totalPrice = 0


menuLabel = tkinter.Label(window, text = '메뉴', width=5, height=1, bg='burlywood3', fg='black')
menuLabel.place(x=10, y=10)
amountLabel = tkinter.Label(window, text='수량', width=3, height=1, bg='burlywood3', fg='black')
amountLabel.place(x=108, y=10)
upLabel = tkinter.Label(window, text = '↑', width=1, height=1, bg='burlywood3', fg='black')
upLabel.place(x=150, y=10)
downLabel = tkinter.Label(window, text = '↓', width=1, height=1, bg='burlywood3', fg='black')
downLabel.place(x=80, y=10)
priceLabel = tkinter.Label(window, text = '가격', width=6, height=1, bg='burlywood3', fg='black')
priceLabel.place(x=185, y=10)


menuLabelM0 = tkinter.Label(window, text = '김치전', width=5, height=1, bg='white', fg='black')
menuLabelM0.place(x=10, y= 50)
labelM0 = tkinter.Label(window, text= '0', width=3, height=1, bd='1', bg='white', fg='black')
labelM0.place(x = 108, y=50)
count_up = tkinter.Button(window, relief = 'ridge',overrelief = 'sunken', activebackground='peachpuff1', text='+', width=1, height=1, command= countUpM0, bd= '0', bg='white', fg='black')
count_up.place(x = 150, y=47.5)
count_up = tkinter.Button(window, relief = 'ridge',overrelief = 'sunken', activebackground='peachpuff1', text='-', width=1, height=1, command=countDownM0, bd ='0', bg='white', fg='black')
count_up.place(x = 80, y=47.5)
priceLabelM0 = tkinter.Label(window, text='0', width=6, height=1, bg='white', fg='black')
priceLabelM0.place(x=185, y=50)

menuLabelM1 = tkinter.Label(window, text = '파전', width=5, height=1, bg='white', fg='black')
menuLabelM1.place(x=10, y= 90)
labelM1 = tkinter.Label(window, text= '0', width=3, height=1, bg='white', fg='black')
labelM1.place(x = 108, y=90)
count_up = tkinter.Button(window, text='+', relief = 'ridge',overrelief = 'sunken', activebackground='peachpuff1', width=1, height=1, command= countUpM1, bd='0', bg='white', fg='black')
count_up.place(x = 150, y=87.5)
count_up = tkinter.Button(window, text='-', relief = 'ridge',overrelief = 'sunken', activebackground='peachpuff1', width=1, height=1, command=countDownM1,bd='0', bg='white', fg='black')
count_up.place(x = 80, y=87.5)
priceLabelM1 = tkinter.Label(window, text='0', width=6, height=1, bg='white', fg='black')
priceLabelM1.place(x=185, y=90)

menuLabelM2 = tkinter.Label(window, text = '막걸리', width=5, height=1, bg='white', fg='black')
menuLabelM2.place(x=10, y= 130)
labelM2 = tkinter.Label(window, text= '0', width=3, height=1, bg='white', fg='black')
labelM2.place(x = 108, y=130)
count_up = tkinter.Button(window, text='+', relief = 'ridge',overrelief = 'sunken', activebackground='peachpuff1', width=1, height=1, command= countUpM2, bd='0', bg='white', fg='black')
count_up.place(x = 150, y=127.5)
count_up = tkinter.Button(window, text='-', relief = 'ridge',overrelief = 'sunken', activebackground='peachpuff1', width=1, height=1, command=countDownM2, bd='0', bg='white', fg='black')
count_up.place(x = 80, y=127.5)
priceLabelM2 = tkinter.Label(window, text='0', width=6, height=1, bg='white', fg='black')
priceLabelM2.place(x=185, y=130)

menuLabelM3 = tkinter.Label(window, text = '참이슬', width=5, height=1, bg='white', fg='black')
menuLabelM3.place(x=10, y= 170)
labelM3 = tkinter.Label(window, text= '0', width=3, height=1, bg='white', fg='black')
labelM3.place(x = 108, y=170)
count_up = tkinter.Button(window, text='+', relief = 'ridge',overrelief = 'sunken', activebackground='peachpuff1', width=1, height=1, command= countUpM3, bd='0', bg='white', fg='black')
count_up.place(x = 150, y=167.5)
count_up = tkinter.Button(window, text='-', relief = 'ridge',overrelief = 'sunken', activebackground='peachpuff1', width=1, height=1, command=countDownM3, bd='0', bg='white', fg='black')
count_up.place(x = 80, y=167.5)
priceLabelM3 = tkinter.Label(window, text='0', width=6, height=1, bg='white', fg='black')
priceLabelM3.place(x=185, y=170)

menuLabelM4 = tkinter.Label(window, text = '테라', width=5, height=1, bg='white', fg='black')
menuLabelM4.place(x=10, y= 210)
labelM4 = tkinter.Label(window, text= '0', width=3, height=1, bg='white', fg='black')
labelM4.place(x = 108, y=210)
count_up = tkinter.Button(window, text='+', relief = 'ridge',overrelief = 'sunken', activebackground='peachpuff1', width=1, height=1, command= countUpM4, bd='0', bg='white', fg='black')
count_up.place(x = 150, y=207.5)
count_up = tkinter.Button(window, text='-', relief = 'ridge',overrelief = 'sunken', activebackground='peachpuff1', width=1, height=1, command=countDownM4, bd='0', bg='white', fg='black')
count_up.place(x = 80, y=207.5)
priceLabelM4 = tkinter.Label(window, text='0', width=6, height=1, bg='white', fg='black')
priceLabelM4.place(x=185, y=210)

menuLabelM5 = tkinter.Label(window, text = '사이다', width=5, height=1, bg='white', fg='black')
menuLabelM5.place(x=10, y= 250)
labelM5 = tkinter.Label(window, text= '0', width=3, height=1, bg='white', fg='black')
labelM5.place(x = 108, y=250)
count_up = tkinter.Button(window, text='+', relief = 'ridge',overrelief = 'sunken', activebackground='peachpuff1', width=1, height=1, command= countUpM5, bd='0', bg='white', fg='black')
count_up.place(x = 150, y=247.5)
count_up = tkinter.Button(window, text='-', relief = 'ridge',overrelief = 'sunken', activebackground='peachpuff1', width=1, height=1, command=countDownM5, bd='0', bg='white', fg='black')
count_up.place(x = 80, y=247.5)
priceLabelM5 = tkinter.Label(window, text='0', width=6, height=1, bg='white', fg='black')
priceLabelM5.place(x=185, y=250)

yourPriceLabel1 = tkinter.Label(window, text='총 금액', bg='white', fg='black')
yourPriceLabel1.place(x=10, y=310)

yourPriceLabel2 = tkinter.Label(window, text = str(totalPrice), width=6, height=1, bg='white', fg='black')
yourPriceLabel2.place(x=185, y=310)

program_exit = tkinter.Button(window, text='주문완료', width=7, height=1, command= buttonExit, bd='0.5', bg='burlywood3', fg='black')
program_exit.place(x = 170, y=380)

window.mainloop()
# Out:
# 주문 내역
#
# 김치전            2     20000원
# 파전              2     24000원
# 막걸리            1      7000원
# 테라              3     15000원
# 사이다            4      8000원
#
# 결제 금액			       74000원
